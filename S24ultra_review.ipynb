# %%
import pandas as pd

# %%
pd.read_json(r"C:\Users\akash\Documents\Web_Screping\IMDb\Project\S24_review.json")
# Out:
#                Buyer_name  Rating  \
# 0          himanshu mehta       5
# 1         Prashant  Gupta       5
# 2         Narendra  Singh       5
# 3           Amit Kottawar       5
# 4             Amol Mahind       5
# ...                   ...     ...
# 1445        Zishan Ansari       5
# 1446    Sunil Kumar Nayak       5
# 1447         Abhishek Jha       5
# 1448  Kuntal Kumar Haldar       5
# 1449    Flipkart Customer       5
#
#                                                  Review
# 0                    Best in night photographyREAD MORE
# 1     Awesome product. Best display, best camera, be...
# 2                         Amazing Products 👏 🤩READ MORE
# 3     Superb product great in every aspect. Go for i...
# 4     Awesome Display and Camera.Battery performance...
# ...                                                 ...
# 1445  ITS A Beast. Performance  too Good Can't wait ...
# 1446               Excellent performance phoneREAD MORE
# ...
